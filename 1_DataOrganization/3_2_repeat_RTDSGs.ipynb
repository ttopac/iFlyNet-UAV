# %%
import pickle
import time
import os
import datetime
import numpy as np
import pandas as pd

cur_dir = os.getcwd()
main_dir = os.path.dirname(os.path.dirname(cur_dir))

# %%
test_dates = ["08_01_2022", "08_02_2022"]
test_folders = ["Day1_Training1", "Day2_Training1"]
rtdstr_filenames = ["compensated_normalized_WTRUN2_training_sweep1_2022-08-01_17-24-43-50_rtd-str_uniqueRTDs_infrequent",
                    "compensated_normalized_WTRUN2_day2_training1_2022-08-02_12-38-30-01_rtd-str_uniqueRTDs_infrequent"]

eds_rtdstr_offsets_dir = os.path.join(cur_dir, "offset_pickles")

# %%
#Load in and arrange the data.
sg_repeated_colnames = ["SG 1 (V) (normalized) (compensated)",
                        "SG 2 (V) (normalized) (compensated)",
                        "SG 4 (V) (normalized) (compensated)",
                        "SG 5 (V) (normalized) (compensated)",
                        "SG 6 (V) (normalized) (compensated)",
                        "SG TE (V) (normalized)",
                        "SG LE (V) (normalized)"]

# Read in the offsets in IMGenie data. We'll use these values to crop out any extra lingering lines.
with open(os.path.join(eds_rtdstr_offsets_dir,'eds_rtdstr_offsets.pkl'), 'rb') as f:
  eds_rtdstr_offsets = pickle.load(f)
with open(os.path.join(eds_rtdstr_offsets_dir,'rtdstr_offsets_trailing.pkl'), 'rb') as f:
  rtdstr_offsets_trailing = pickle.load(f)

# %%
###
#Cleaning and repetition for all the data
###

sg_dfs = list()

for i in range(len(test_folders)):
  ###
  #First modify them according to the edits we made to the overall files (mainly crops due to different start times of EDS & UAV)
  ###
  data_dir = os.path.join(main_dir, test_dates[i]+"_Tests", "testdata", test_folders[i])
  
  #Read the RTDSTR file
  rtdstr_filename = rtdstr_filenames[i]
  rtdstr_file_csv = os.path.join(data_dir, rtdstr_filename)
  rtdstr_file_df = pd.read_csv(rtdstr_file_csv+".csv", header=0)
  rtdstr_file_df_edited = rtdstr_file_df

  #Insert proper time object
  month = int (test_dates[i][0:2])
  day = int (test_dates[i][3:5])
  year = int (test_dates[i][6:])
  rtdstr_times = rtdstr_file_df["Date/Time"].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d_%H-%M-%S-%f"))
  rtdstr_times = rtdstr_times.apply(lambda x: datetime.datetime(year, month, day, x.hour, x.minute, x.second, x.microsecond)) #We do this because we haven't recorded date in the original data.
  if "rtdstr_DateTime Obj" not in rtdstr_file_df_edited.columns:
    rtdstr_file_df_edited.insert(1, "rtdstr_DateTime Obj", rtdstr_times)
  else:
    rtdstr_file_df_edited["rtdstr_DateTime Obj"] = rtdstr_file_df_edited["rtdstr_DateTime Obj"].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S.%f"))
    
  if eds_rtdstr_offsets[i][0] != "rtdstr": #if vantage[i] is not rtdstr (meaning that rtdstr started earlier, so some of it was cut).
    #Determine how many seconds of IMGenie data we cut when aligning the data and crop out that many lines from PZT data.
    rtdstr_file_df_edited = rtdstr_file_df_edited.iloc[eds_rtdstr_offsets[i][1]:]
  
  if rtdstr_offsets_trailing[i] != -1: #if vantage[i] is not rtdstr (meaning that rtdstr ended later, so some of it was cut).
    rtdstr_file_df_edited = rtdstr_file_df_edited.iloc[:rtdstr_offsets_trailing[i]+1]
    
  sg_dfs.append(rtdstr_file_df_edited)

# %%
### BEWARE: BE CAREFUL NOT TO RUN THIS BLOCK MORE THAN ONCE TIMES AS coarse_times IS MODIFIED INSIDE 
### AND RUNNING MULTIPLE TIMES WOULD GENERATE VERY INCONSISTENT DATA. 
### ALWAYS RUN THE BLOCK ABOVE RIGHT BEFORE RUNNING THIS

###
#Then add repeated lines to the SG/RTD data
###
def construct_repeated_sgs(fine_times, coarse_times, SG_vals):
  #fine_times: shape(# lines in consolidated pzt)
  #coarse_times: shape(# lines in consolidated rtd/sg)
  #SG_vals: shape(coarse_times.shape[0], 7)

  SG_vals_interp = np.zeros((fine_times.shape[0], SG_vals.shape[1]))
  prev_time = coarse_times[0]
  next_time_ix = 5 #This is 5 here to avoid any repeated lines at the beginning.
  next_time = coarse_times[next_time_ix]
  coarse_delta = next_time-prev_time
  
  for line_ix in range(len(fine_times)-10000): #We're ignoring the last 1 second to avoid index errors.
    fine_time = fine_times[line_ix]
    if line_ix % 1000000 == 0:
      print (f"{float(line_ix/len(fine_times)*100)} percent is complete.")
    if next_time - fine_time < np.timedelta64(100,"us"):
      prev_time = next_time
      next_time_ix += 1
      time_ixs_rep_cnt = 1
      while coarse_times[next_time_ix] == coarse_times[next_time_ix+time_ixs_rep_cnt]:
        time_ixs_rep_cnt += 1
      if time_ixs_rep_cnt != 1:
        prior_time = coarse_times[next_time_ix-1]
        next_time = coarse_times[next_time_ix+time_ixs_rep_cnt]
        time_delta = next_time - prior_time
        time_increment = time_delta/(time_ixs_rep_cnt+1)
        for i in range(time_ixs_rep_cnt):
          coarse_times[next_time_ix+i] = prior_time + time_increment*(i+1)
      next_time = coarse_times[next_time_ix]
      coarse_delta = next_time-prev_time

    t1 = fine_time - prev_time
    time_ratio = t1/coarse_delta
    SG_vals_interp[line_ix] = SG_vals[next_time_ix-1]*(1-time_ratio) + SG_vals[next_time_ix]*time_ratio
  return SG_vals_interp

repeated_sg_data = list()   
for sg_df in sg_dfs:
  pzt_times_reconstruct = np.arange(sg_df['rtdstr_DateTime Obj'].iloc[0], sg_df['rtdstr_DateTime Obj'].iloc[-1], datetime.timedelta(0,1/10000))
  SG_vals_interp = construct_repeated_sgs(pzt_times_reconstruct, sg_df['rtdstr_DateTime Obj'].to_numpy(), sg_df[sg_repeated_colnames].to_numpy())
  repeated_sg_data.append({"pzt_times_reconstruct":pzt_times_reconstruct, "SG_vals_interp":SG_vals_interp})
# Out:
# 0.0 percent is complete.
# 0.6440514442531612 percent is complete.
# 1.2881028885063224 percent is complete.
# 1.9321543327594832 percent is complete.
# 2.5762057770126447 percent is complete.
# 3.220257221265806 percent is complete.
# 3.8643086655189665 percent is complete.
# 4.508360109772128 percent is complete.
# 5.1524115540252895 percent is complete.
# 5.79646299827845 percent is complete.
# 6.440514442531612 percent is complete.
# 7.084565886784773 percent is complete.
# 7.728617331037933 percent is complete.
# 8.372668775291094 percent is complete.
# 9.016720219544256 percent is complete.
# 9.660771663797417 percent is complete.
# 10.304823108050579 percent is complete.
# 10.94887455230374 percent is complete.
# 11.5929259965569 percent is complete.
# 12.236977440810062 percent is complete.
# 12.881028885063223 percent is complete.
# 13.525080329316385 percent is complete.
# 14.169131773569546 percent is complete.
# 14.813183217822706 percent is complete.
# 15.457234662075866 percent is complete.
# 16.10128610632903 percent is complete.
# 16.74533755058219 percent is complete.
# 17.38938899483535 percent is complete.
# 18.033440439088512 percent is complete.
# 18.677491883341673 percent is complete.
# 19.321543327594835 percent is complete.
# 19.965594771847996 percent is complete.
# 20.609646216101158 percent is complete.
# 21.253697660354316 percent is complete.
# 21.89774910460748 percent is complete.
# 22.541800548860643 percent is complete.
# 23.1858519931138 percent is complete.
# 23.829903437366966 percent is complete.
# 24.473954881620124 percent is complete.
# 25.11800632587329 percent is complete.
# 25.762057770126447 percent is complete.
# 26.406109214379608 percent is complete.
# 27.05016065863277 percent is complete.
# 27.694212102885928 percent is complete.
# 28.338263547139093 percent is complete.
# 28.982314991392254 percent is complete.
# 29.626366435645412 percent is complete.
# 30.270417879898577 percent is complete.
# 30.91446932415173 percent is complete.
# 31.558520768404897 percent is complete.
# 32.20257221265806 percent is complete.
# 32.84662365691122 percent is complete.
# 33.49067510116438 percent is complete.
# 34.13472654541754 percent is complete.
# 34.7787779896707 percent is complete.
# 35.422829433923866 percent is complete.
# 36.066880878177024 percent is complete.
# 36.71093232243018 percent is complete.
# 37.35498376668335 percent is complete.
# 37.99903521093651 percent is complete.
# 38.64308665518967 percent is complete.
# 39.28713809944283 percent is complete.
# 39.93118954369599 percent is complete.
# 40.57524098794915 percent is complete.
# 41.219292432202316 percent is complete.
# 41.86334387645548 percent is complete.
# 42.50739532070863 percent is complete.
# 43.1514467649618 percent is complete.
# 43.79549820921496 percent is complete.
# 44.43954965346812 percent is complete.
# 45.083601097721285 percent is complete.
# 45.72765254197444 percent is complete.
# 46.3717039862276 percent is complete.
# 47.015755430480766 percent is complete.
# 47.65980687473393 percent is complete.
# 48.30385831898709 percent is complete.
# 48.94790976324025 percent is complete.
# 49.59196120749341 percent is complete.
# 50.23601265174658 percent is complete.
# 50.880064095999735 percent is complete.
# 51.52411554025289 percent is complete.
# 52.16816698450606 percent is complete.
# 52.812218428759216 percent is complete.
# 53.456269873012374 percent is complete.
# 54.10032131726554 percent is complete.
# 54.7443727615187 percent is complete.
# 55.388424205771855 percent is complete.
# 56.03247565002503 percent is complete.
# 56.676527094278185 percent is complete.
# 57.32057853853134 percent is complete.
# 57.96462998278451 percent is complete.
# 58.608681427037666 percent is complete.
# 59.252732871290824 percent is complete.
# 59.896784315544 percent is complete.
# 60.540835759797154 percent is complete.
# 61.18488720405031 percent is complete.
# 61.82893864830346 percent is complete.
# 62.472990092556635 percent is complete.
# 63.11704153680979 percent is complete.
# 63.76109298106295 percent is complete.
# 64.40514442531612 percent is complete.
# 65.04919586956927 percent is complete.
# 65.69324731382244 percent is complete.
# 66.3372987580756 percent is complete.
# 66.98135020232876 percent is complete.
# 67.62540164658192 percent is complete.
# 68.26945309083509 percent is complete.
# 68.91350453508824 percent is complete.
# 69.5575559793414 percent is complete.
# 70.20160742359457 percent is complete.
# 70.84565886784773 percent is complete.
# 71.48971031210088 percent is complete.
# 72.13376175635405 percent is complete.
# 72.77781320060721 percent is complete.
# 73.42186464486036 percent is complete.
# 74.06591608911354 percent is complete.
# 74.7099675333667 percent is complete.
# 75.35401897761986 percent is complete.
# 75.99807042187302 percent is complete.
# 76.64212186612617 percent is complete.
# 77.28617331037934 percent is complete.
# 77.9302247546325 percent is complete.
# 78.57427619888566 percent is complete.
# 79.21832764313882 percent is complete.
# 79.86237908739199 percent is complete.
# 80.50643053164515 percent is complete.
# 81.1504819758983 percent is complete.
# 81.79453342015147 percent is complete.
# 82.43858486440463 percent is complete.
# 83.08263630865778 percent is complete.
# 83.72668775291096 percent is complete.
# 84.37073919716411 percent is complete.
# 85.01479064141726 percent is complete.
# 85.65884208567044 percent is complete.
# 86.3028935299236 percent is complete.
# 86.94694497417676 percent is complete.
# 87.59099641842992 percent is complete.
# 88.23504786268307 percent is complete.
# 88.87909930693624 percent is complete.
# 89.5231507511894 percent is complete.
# 90.16720219544257 percent is complete.
# 90.81125363969572 percent is complete.
# 91.45530508394889 percent is complete.
# 92.09935652820205 percent is complete.
# 92.7434079724552 percent is complete.
# 93.38745941670837 percent is complete.
# 94.03151086096153 percent is complete.
# 94.67556230521468 percent is complete.
# 95.31961374946786 percent is complete.
# 95.96366519372101 percent is complete.
# 96.60771663797418 percent is complete.
# 97.25176808222734 percent is complete.
# 97.8958195264805 percent is complete.
# 98.53987097073366 percent is complete.
# 99.18392241498682 percent is complete.
# 99.82797385923999 percent is complete.
# 0.0 percent is complete.
# 1.806338804131458 percent is complete.
# 3.612677608262916 percent is complete.
# 5.419016412394375 percent is complete.
# 7.225355216525832 percent is complete.
# 9.03169402065729 percent is complete.
# 10.83803282478875 percent is complete.
# 12.644371628920206 percent is complete.
# 14.450710433051665 percent is complete.
# 16.257049237183125 percent is complete.
# 18.06338804131458 percent is complete.
# 19.86972684544604 percent is complete.
# 21.6760656495775 percent is complete.
# 23.482404453708956 percent is complete.
# 25.288743257840412 percent is complete.
# 27.09508206197187 percent is complete.
# 28.90142086610333 percent is complete.
# 30.707759670234786 percent is complete.
# 32.51409847436625 percent is complete.
# 34.32043727849771 percent is complete.
# 36.12677608262916 percent is complete.
# 37.93311488676062 percent is complete.
# 39.73945369089208 percent is complete.
# 41.545792495023534 percent is complete.
# 43.352131299155 percent is complete.
# 45.158470103286454 percent is complete.
# 46.96480890741791 percent is complete.
# 48.77114771154937 percent is complete.
# 50.577486515680825 percent is complete.
# 52.38382531981228 percent is complete.
# 54.19016412394374 percent is complete.
# 55.996502928075195 percent is complete.
# 57.80284173220666 percent is complete.
# 59.609180536338116 percent is complete.
# 61.41551934046957 percent is complete.
# 63.22185814460103 percent is complete.
# 65.0281969487325 percent is complete.
# 66.83453575286396 percent is complete.
# 68.64087455699541 percent is complete.
# 70.44721336112687 percent is complete.
# 72.25355216525833 percent is complete.
# 74.05989096938978 percent is complete.
# 75.86622977352124 percent is complete.
# 77.6725685776527 percent is complete.
# 79.47890738178415 percent is complete.
# 81.28524618591561 percent is complete.
# 83.09158499004707 percent is complete.
# 84.89792379417852 percent is complete.
# 86.70426259831 percent is complete.
# 88.51060140244145 percent is complete.
# 90.31694020657291 percent is complete.
# 92.12327901070437 percent is complete.
# 93.92961781483582 percent is complete.
# 95.73595661896728 percent is complete.
# 97.54229542309874 percent is complete.
# 99.34863422723019 percent is complete.

# %%
df_save_dir = os.path.join(main_dir, "ConsolidatedData", "Training1")
repeated_sg_dfs = list()

for ix, repeated_sg_dat in enumerate(repeated_sg_data):
  repeated_sg_df = pd.DataFrame(repeated_sg_dat["SG_vals_interp"], columns=sg_repeated_colnames)
  repeated_sg_df["repeated_DateTime Obj"] = repeated_sg_dat["pzt_times_reconstruct"]
  repeated_sg_df.to_pickle(os.path.join(df_save_dir,f'consolidated_repeated_sg_{ix}_uniqueRTDs_infrequent.pkl'))
  repeated_sg_dfs.append(repeated_sg_df)

concated_all_sg_df = pd.concat((repeated_sg_df for repeated_sg_df in repeated_sg_dfs), ignore_index=True)
concated_all_sg_df.to_pickle(os.path.join(df_save_dir,f'consolidated_repeated_sg_all_uniqueRTDs_infrequent.pkl'))
